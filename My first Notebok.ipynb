# %%
import urllib3

link = "https://www.metacritic.com/browse/movies/score/metascore/year/filtered?year_selected=1999&sort=desc&view=detailed"

# Construct a python request pool
urllib3.disable_warnings()
http = urllib3.PoolManager(cert_reqs='CERT_NONE')

# Initiate a web request
r = http.request('GET', link, headers={'User-Agent': 'Mozilla/5.0'})

# Convert the result from raw bytes to text
datastring = str(r.data, "utf-8")

# Check whether it succeeded and how much data we got from the site
print(r.status)
print(len(datastring))

import re
# Search for titles, release dates, summary, images, metascore
title = re.findall("class=\"title\"><h3>(.*)</h3><\/a>", datastring)
ReleaseDates = re.findall("<div class=\"clamp-details\">\s+ <span>(.*)<\/span>", datastring)
Description = re.findall("<div class=\"summary\">\n\s+(.*)", datastring)
meta = re.findall("<div class=\"metascore_w large movie positive\">(.*)"
                "<\/div>\n\s+<\/a>\n\s+<\/div>\n\s+<div class=\"clamp-userscore\">", datastring)
thumb = re.findall("<img src=\"(.*)\" alt=\"(?:.*)\" \/><\/a>", datastring)

#using for loop to append found information to create a movie list. 
movies = []

for i in range(len(title)):
    movies.append("Movie Title: " + title[i] + "\n"
                "Release Date: " + ReleaseDates[i] + "\n"
                "Summary: " + Description[i] + "\n"
                "Metascore: " + meta[i] + "\n"
                "Image URL: " + thumb[i])
#while loop to append found information to create a movie list.
i = 0
while i <len(movies):
    print(movies[i] + "\n")
    i = i +1    
import pyodbc            

import json



with open('C:\\Users\\SETUPUSER\\Documents\\GitHub\\Meta-Project\\credentials.json') as f:
    data = json.load(f)
    connstr = data['connection string']
    username = data['username']
    password = data['password']
print('My username is ' + username)
print('My password is ' + password)

#Connect to the database

conn = pyodbc.connect(connstr)

Cursor = conn.cursor()

import pyodbc 

conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=DESKTOP-B1LT8Q0\SQLEXPRESS;'
                      'Database=DA320;'
                      'Trusted_Connection=yes;')

cursor = conn.cursor()

for i in range(0, len(title)):
    
    args = title[i], ReleaseDates[i], Description[i], thumb[i],meta[i]

    cursor.execute( "INSERT INTO movies (movie_name, release_date, Description, thumbnail, metascore) values (?,?,?,?,?)", args)

cursor.commit()
# Out:
# 200
# 483227
# Movie Title: After Life
# Release Date: May 12, 1999
# Summary: After death, people have just one week to choose only a memory to keep for eternity.
# Metascore: 91
# Image URL: https://static.metacritic.com/images/products/movies/0/02e75fa50dc838bbd68276234e4f8c65-98.jpg
#
# Movie Title: Topsy-Turvy
# Release Date: December 17, 1999
# Summary: When their latest play fails and they threaten to disband, Gilbert and Sullivan are inspired to create their masterpiece, "The Mikado."
# Metascore: 90
# Image URL: https://static.metacritic.com/images/products/movies/6/8258920dddb375fc92d3df33549da5ed-98.jpg
#
# Movie Title: Being John Malkovich
# Release Date: October 29, 1999
# Summary: An out-of-work puppeteer takes a filing clerk job on the cramped 7 ½ floor of an office building where he discovers a hidden tunnel allowing him to enter the mind and life of actor John Malkovich for 15 mintues before being ejected onto the New Jersey Turnpike.
# Metascore: 90
# ...

# %%
import re
# Search for titles, release dates, summary, images, metascore
title = re.findall("class=\"title\"><h3>(.*)<\/a>", datastring)
ReleaseDates = re.findall("<div class=\"clamp-details\">\s+ <span>(.*)<\/span>", datastring)
Description = re.findall("<div class=\"summary\">\n\s+(.*)", datastring)
meta = re.findall("<div class=\"metascore_w large movie positive\">(.*)"
                "<\/div>\n\s+<\/a>\n\s+<\/div>\n\s+<div class=\"clamp-userscore\">", datastring)
thumb = re.findall("<img src=\"(.*)\" alt=\"(?:.*)\" \/><\/a>", datastring)

#using for loop to append found information to create a movie list. 
movies = []

for i in range(len(title)):
    movies.append("Movie Title: " + title[i] + "\n"
                "Release Date: " + ReleaseDates[i] + "\n"
                "Summary: " + Description[i] + "\n"
                "Metascore: " + meta[i] + "\n"
                "Image URL: " + thumb[i])
#while loop to append found information to create a movie list.
i = 0
while i <len(movies):
    print(movies[i] + "\n")
    i = i +1    
import pyodbc            

import json



with open('C:\\Users\\SETUPUSER\\Documents\\GitHub\\Meta-Project\\credentials.json') as f:
    data = json.load(f)
    connstr = data['connection string']
    username = data['username']
    password = data['password']
print('My username is ' + username)
print('My password is ' + password)

#Connect to the database

conn = pyodbc.connect(connstr)

Cursor = conn.cursor()

import pyodbc 

conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=DESKTOP-B1LT8Q0\SQLEXPRESS;'
                      'Database=DA320;'
                      'Trusted_Connection=yes;')

cursor = conn.cursor()
cursor.execute('SELECT * FROM movies')
for i in cursor:
    print(i)

args = title[i], ReleaseDates[i], Description[i], meta[i], thumb[i]

cursor.execute( "INSERT INTO movies (title, ReleaseDates, Description, meta, thumb) values '(?,?,?,?)'", args)
# Out:
# Movie Title: After Life</h3>
# Release Date: May 12, 1999
# Summary: After death, people have just one week to choose only a memory to keep for eternity.
# Metascore: 91
# Image URL: https://static.metacritic.com/images/products/movies/0/02e75fa50dc838bbd68276234e4f8c65-98.jpg
#
# Movie Title: Topsy-Turvy</h3>
# Release Date: December 17, 1999
# Summary: When their latest play fails and they threaten to disband, Gilbert and Sullivan are inspired to create their masterpiece, "The Mikado."
# Metascore: 90
# Image URL: https://static.metacritic.com/images/products/movies/6/8258920dddb375fc92d3df33549da5ed-98.jpg
#
# Movie Title: Being John Malkovich</h3>
# Release Date: October 29, 1999
# Summary: An out-of-work puppeteer takes a filing clerk job on the cramped 7 ½ floor of an office building where he discovers a hidden tunnel allowing him to enter the mind and life of actor John Malkovich for 15 mintues before being ejected onto the New Jersey Turnpike.
# Metascore: 90
# ...

# %%
import pyodbc            

import json



with open('C:\\Users\\SETUPUSER\\Documents\\GitHub\\Meta-Project\\credentials.json') as f:
    data = json.load(f)
    connstr = data['connection string']
    username = data['username']
    password = data['password']
print('My username is ' + username)
print('My password is ' + password)

#Connect to the database

conn = pyodbc.connect(connstr)

Cursor = conn.cursor()

import pyodbc 

conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=DESKTOP-B1LT8Q0\SQLEXPRESS;'
                      'Database=DA320;'
                      'Trusted_Connection=yes;')

cursor = conn.cursor()
cursor.execute('SELECT * FROM movies')
for i in cursor:
    print(i)

args = title[i], ReleaseDates[i], Description[i], meta[i], thumb[i]

cursor.execute( "INSERT INTO movies (title, ReleaseDates, Description, meta, thumb) values '(?,?,?,?)'", args)
# Out:
# My username is Ame
# My password is Admiral

# %%
import pyodbc 

conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=DESKTOP-B1LT8Q0\SQLEXPRESS;'
                      'Database=DA320;'
                      'Trusted_Connection=yes;')

cursor = conn.cursor()
cursor.execute('SELECT * FROM movies')
for i in cursor:
    print(i)

args = title[i], ReleaseDates[i], Description[i], meta[i], thumb[i]

cursor.execute( "INSERT INTO movies (title, ReleaseDates, Description, meta, thumb) values '(?,?,?,?)'", args)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f7a1d02dea40> in <module>
# ----> 1 args = title[i], ReleaseDates[i], Description[i], meta[i], thumb[i]
#       2
#       3 cursor.execute( "INSERT INTO movies (title, ReleaseDates, Description, meta, thumb) values '(?,?,?,?)'", args)
#
# NameError: name 'title' is not defined
