# %%
import json 

with open('f:\\git\\credentials.json') as f:
    data = json.load(f)
    MongoDBConnectionString = data['connection string']
    username = data['user']
    password = data['pass']
    MongoDB = data['MongoDBConnectionString']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\SETUPUSER\Documents\GitHub\Meta-Project\mongoDB_charting.ipynb Cell 1' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/SETUPUSER/Documents/GitHub/Meta-Project/mongoDB_charting.ipynb#ch0000000?line=0'>1</a> import json
# ----> <a href='vscode-notebook-cell:/c%3A/Users/SETUPUSER/Documents/GitHub/Meta-Project/mongoDB_charting.ipynb#ch0000000?line=2'>3</a> with open('f:\\git\\credentials.json') as f:
#       <a href='vscode-notebook-cell:/c%3A/Users/SETUPUSER/Documents/GitHub/Meta-Project/mongoDB_charting.ipynb#ch0000000?line=3'>4</a>     data = json.load(f)
#       <a href='vscode-notebook-cell:/c%3A/Users/SETUPUSER/Documents/GitHub/Meta-Project/mongoDB_charting.ipynb#ch0000000?line=4'>5</a>     MongoDBConnectionString = data['connection string']
#
# FileNotFoundError: [Errno 2] No such file or directory: 'f:\\git\\credentials.json'

# %%
import pymongo
