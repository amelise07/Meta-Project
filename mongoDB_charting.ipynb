# %%
import json 

with open('f:\\C:\\Users\\SETUPUSER\\Documents\\GitHub\\Meta-Project\\credentials.json') as f:
    data = json.load(f)
    MongoDBConnectionString = data['connection string']
    username = data['user']
    password = data['pass']
    MongoDB = data['MongoDBConnectionString']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-a05b1a9a67b4> in <module>
#       1 import json
#       2
# ----> 3 with open('f:\\C:\\Users\\SETUPUSER\\Documents\\GitHub\\Meta-Project\\credentials.json') as f:
#       4     data = json.load(f)
#       5     MongoDBConnectionString = data['connection string']
#
# FileNotFoundError: [Errno 2] No such file or directory: 'f:\\C:\\Users\\SETUPUSER\\Documents\\GitHub\\Meta-Project\\credentials.json'
