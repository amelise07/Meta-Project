# %%
# import plotting tool for low level graph
import matplotlib.pyplot as plt
plt.style.use('')
import numpy as np
import json 
import pyodbc

#json file for security
with open('C:\Users\SETUPUSER\Documents\GitHub\Meta-Project\credentials.json') as f:
    data = json.load(f)
    username = ['username']
    password = ['password']
    connstring = data['"Driver={SQL Server};Server=DESKTOP-B1LT8Q0\\SQLEXPRESS;Database=DA320;Trusted_Connection=yes;"']
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <module>
#       1 # import plotting tool for low level graph
# ----> 2 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'
