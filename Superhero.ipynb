# %%
# import plotting tool for low level graph
import sys
import matplotlib
matplotlib.use('Agg')

import matplotlib.pyplot as plt
import numpy as np
import json 
import pyodbc

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o')
plt.show()


plt.savefig(sys.stdout.buffer)
sys.stdout.flush()

#json file for security
with open('C:\Users\SETUPUSER\Documents\GitHub\Meta-Project\credentials.json') as f:
    data = json.load(f)
    username = ['username']
    password = ['password']
    connstring = data['"Driver={SQL Server};Server=DESKTOP-B1LT8Q0\\SQLEXPRESS;Database=DA320;Trusted_Connection=yes;"']

    #Connecting to Sql Server
    conn = pyodbc.connect (connstring) 

    cursor=connstring.cursor()

    # Sql statement to connect making a chart with rawmoovies that are not null because that data is irrelevant
    sql = 'dbo.pytho_movies'
        cursor.execute.(sql)
        rows = cursor.fetchall()
        #print(rows)
        cursor.commit()

    #adjustments on rows like the x and y axis with the title as well
        for row in rows:
            plt.plot(row[0], row[1], 'x')
        plt.title("Highest gross movie genres")
        plt.xlabel("")
        plt.ylabel("")

        conn.close
# Out:
#   File "<ipython-input-3-cab2a54582e0>", line 9
#     with open('C:\Users\SETUPUSER\Documents\GitHub\Meta-Project\credentials.json') as f:
#              ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
